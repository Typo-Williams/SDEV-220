# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # SF Salaries Exercise
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [SF Salaries Dataset](https://www.kaggle.com/kaggle/sf-salaries) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# ** Import pandas as pd.**

# %%
import pandas as pd

# %% [markdown]
# ** Read Salaries.csv as a dataframe called sal.**

# %%
sal = pd.read_csv('Salaries.csv')
sal
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %% [markdown]
# ** Check the head of the DataFrame. **

# %%
sal.head
# Out:
# <bound method NDFrame.head of             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# ...

# %% [markdown]
# ** Use the .info() method to find out how many entries there are.**

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %% [markdown]
# **What is the average BasePay ?**

# %%
sal['BasePay'].mean()
# Out:
# 66325.44884050643

# %% [markdown]
# ** What is the highest amount of OvertimePay in the dataset ? **

# %%
sal['OvertimePay'].max()
# Out:
# 245131.88

# %% [markdown]
# ** What is the job title of  JOSEPH DRISCOLL ? Note: Use all caps, otherwise you may get an answer that doesn't match up (there is also a lowercase Joseph Driscoll). **

# %%
sal.loc[sal['EmployeeName'] == 'JOSEPH DRISCOLL'].index[0]
sal.loc[24,'JobTitle']
# Out:
# 'CAPTAIN, FIRE SUPPRESSION'

# %% [markdown]
# ** How much does JOSEPH DRISCOLL make (including benefits)? **

# %%
sal.loc[24, 'TotalPayBenefits']
# Out:
# 270324.91

# %% [markdown]
# ** What is the name of highest paid person (including benefits)?**

# %%
top = sal['TotalPayBenefits'].max()
sal[sal['TotalPayBenefits'] == top]
sal.loc[0,'EmployeeName']
# Out:
# 'NATHANIEL FORD'

# %% [markdown]
# ** What is the name of lowest paid person (including benefits)? Do you notice something strange about how much he or she is paid?**

# %%
sal.loc[sal['TotalPayBenefits'] == 0]
# Out:
#             Id            EmployeeName  \
# 36156    36157          PAULETTE ADAMS
# 36157    36158           KAUKAB MOHSIN
# 36158    36159      JOSEPHINE MCCREARY
# 148626  148627           Paulet Gaines
# 148627  148628        Brett A Lundberg
# 148628  148629          Mark W Mcclure
# 148629  148630       Elizabeth Iniguez
# 148630  148631            Randy J Keys
# 148631  148632         Andre M Johnson
# 148632  148633  Sharon D Owens-Webster
# 148633  148634        Edward Ferdinand
# 148634  148635          David M Turner
# 148635  148636     James S Kibblewhite
# 148636  148637           Andrew J Enzi
# 148637  148638        Kadeshra D Green
# 148638  148639    Lennard B Hutchinson
# 148639  148640       Richard A Talbert
# 148640  148641      Charlene D Mccully
# 148641  148642   Raphael Marquis Goins
# 148642  148643       Dominic C Marquez
# 148643  148644              Kim Brewer
# 148644  148645            Randy D Winn
# 148645  148646        Carolyn A Wilson
# ...

# %% [markdown]
# ** What was the average (mean) BasePay of all employees per year? (2011-2014) ? **

# %%
result1 = sal[(sal['Year'] == 2011) & sal['TotalPayBenefits'] > 0]
result2 = sal[(sal['Year'] == 2012) & sal['TotalPayBenefits'] > 0]
result3 = sal[(sal['Year'] == 2013) & sal['TotalPayBenefits'] > 0]
result4 = sal[(sal['Year'] == 2014) & sal['TotalPayBenefits'] > 0]

print("2011", result1['TotalPayBenefits'].max())
print("2012", result2['TotalPayBenefits'].max())
print("2013", result3['TotalPayBenefits'].max())
print("2014", result4['TotalPayBenefits'].max())
# Out:
# 2011 567595.43
# 2012 407274.78
# 2013 425815.28
# 2014 510732.68

# %% [markdown]
# ** How many unique job titles are there? **

# %%
sal['JobTitle'].nunique()
# Out:
# 2159

# %% [markdown]
# ** What are the top 5 most common jobs? **

# %%
sal['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %% [markdown]
# ** How many Job Titles were represented by only one person in 2013? (e.g. Job Titles with only one occurence in 2013?) **

# %%
sum(sal[sal['Year']==2013]['JobTitle'].value_counts() == 1)
# Out:
# 202

# %% [markdown]
# ** How many people have the word Chief in their job title? (This is pretty tricky) **

# %%
def chiefs(title):
    if 'chief' in title.lower().split():
        return True
    else:
        return False

# %%
sum(sal['JobTitle'].apply(lambda x: chiefs(x)))
# Out:
# 477

# %% [markdown]
# ** Bonus: Is there a correlation between length of the Job Title string and Salary? **

# %%
sal['title_len'] = sal['JobTitle'].apply(len)

# %%
sal[['TotalPayBenefits', 'title_len']].corr()
# Out:
#                   TotalPayBenefits  title_len
# TotalPayBenefits          1.000000  -0.036878
# title_len                -0.036878   1.000000

# %% [markdown]
# # Great Job!
